# %% [markdown]
# <h1 style="color:#EE3377">
#      Robotics Homogeneous Transforms Worksheet
# </h1>
#
#
#
# ## Jennifer Kay <br> kay@rowan.edu <br> Rowan University Computer Science Department
#
# Last update: 2022-10-18
# <p>&nbsp;</p>
# <a rel="license" href="http://creativecommons.org/licenses/by-nc-sa/4.0/"><img align="left" alt="Creative Commons License" style="border-width:0" src="https://i.creativecommons.org/l/by-nc-sa/4.0/88x31.png" /></a><br /><p></p>This work is licensed under a <a rel="license" href="http://creativecommons.org/licenses/by-nc-sa/4.0/">Creative Commons Attribution-NonCommercial-ShareAlike 4.0 International License</a>.
#
# <ul>
#
#
#
# ### Important Note Regarding Reuse of this Work:
# * This work **MAY NOT** be shared on commercial websites that charge users for content.
# * So, for example, it would be a breach of this license to post this (or anything derived from it) on chegg.com
# * Please see: http://creativecommons.org/licenses/by-nc-sa/4.0/  for the nitty gritty details
# </ul>

# %% [markdown]
# <h1 style="color:#EE3377">
#     IMPORTANT FACTOID:
# </h1>
# Once you've created a variable, function, etc. in this notebook, it lives forever unless you either reassign it or restart the Runtime. If you find yourself stuck down a dead end and aren't sure what variables have what values, you may want to:
#
# * Go to the Runtime Menu
# * Select "Restart"
# * Start back at the top of the page and run all the code cells again
#
#
# # <font color=#EE3377> General Instructions
# </font>
#
# * Proceed through this notebook from top to bottom.
# * Read everything carefully! I'll tell you what to do as you go along.
# * I will actually complete problem 1 for you, so that you get some ideas about how to do some of this stuff.

# %% [markdown]
# # Getting started: Step 1
#
# *   When you run the code block immediately following this text block titled "Initialization 1"
#   * It will produce a huge amount of output. You can ignore virtually all of it.
#   * You will know it has finished running because you will see a little check-box to the left of the run icon and also you'll see a message from me reminding you that you may have to restart the runtime
#
#
#
# #<font color='green'>NOW DO THIS:</font>
# * <font color = 'green'>**Run the code block immediately following this text block titled "Initialization 1"** </font>
# * <font color = 'green'>**Restart the runtime**
#   * <font color = 'green'>Runtime menu -> Restart runtime
#   * <font color = 'green'>(It doesn't hurt to do it again even if you don't need to)
#   * <font color = 'green'>(You have to acknowledge that you really want to do this, and variables may be deleted ... that's really OK!)
# * **Run the "Initialization 1 code block a second time!** </font>

# %%
#@title Initialization 1 

import datetime

##########################################################
# Printing a success message so reader feels good
# 
# Also a little bit of a datetime demo

def successMessage(thingToSay="", closer = ""):
  rightNow = datetime.datetime.now()
  rightNowString = rightNow.strftime("%Y-%m-%d %H:%M:%S") 
  stars = stars = "*"*100+"\n"

  header = footer = stars + stars
  line1 = "\n\t\t" + thingToSay + "\n"
  line2 = "\t\t\t"
  line2 += "Finished at " if closer=="" else closer
  line2 += rightNowString + "\n\n"
  
  message = header + line1 + line2 + footer

  print(message)



# !pip install ipympl --quiet
# !pip install requests --quiet



successMessage ("----> If this is your first time running this code in this session then go to <----\n\t\t----> the Runtime menu and click 'restart runtime' and then run it again!! <-----")

# %% [markdown]
# # Getting Started: Step 2
#
# The "Initialization 2" Code below:
# * Just does some
#  imports and customizations for numpy, matplotlib, and sympy
# * You shouldn't need to restart the runtime again
#
# #<font color='green'>NOW DO THIS:</font>
# * <font color = 'green'>**Run the code block immediately following this text block titled "Initialization 2"** </font>

# %%
#@title Initialization 2


#####################################################
# General Imports and numpy / matplotlib / sympy   setup

#allow support for 3rd party widgets (the matplotlib interactive stuff)
from google.colab import output
output.enable_custom_widget_manager()

#you can disable the above by:
#   from google.colab import output
#   output.enable_custom_widget_manager()

#display live figures in the notebook
# %matplotlib ipympl 


#stack overflow says calling a second time may prevent some graphics errors
#%matplotlib notebook 

import matplotlib.pyplot as plt
import numpy as np
import sympy as sp
import math

import requests

# ------------ copy file from url to local runtime environment ------------------- 
def copyFileToRuntime(url, filename):
  r = requests.get(url)
  with open(filename, 'w') as f:
    f.write(r.text)

# Add Dr. Kay's files to colab working directory
url = "https://raw.githubusercontent.com/jenniferskay/kinematics-problems-01/master/pythonFiles/"
filename = "kayHomogeneousTransformations.py"
copyFileToRuntime(url+filename, filename)

filename = "kayHomogeneousTransformGraphics.py"
copyFileToRuntime(url+filename, filename)

filename = "kayColorPalette.py"
copyFileToRuntime(url+filename, filename)


# set all numpy prints to just 3 decimal places
np.set_printoptions(formatter={'float': lambda x: "{0:0.3f}".format(x)})   

# import the code that Dr. Kay wrote
import kayHomogeneousTransformations as ht
import kayHomogeneousTransformGraphics as hg
import kayColorPalette as cp

# %% [markdown]
# # A little more information about Dr. Kay's code that was just loaded in Initialization 2 above
#
# If you open the files tab on the far left, you'll see three files that were just added. You can view them by clicking on the files at the left, or find them on github at the links provided below.
# ## <a href = "https://raw.githubusercontent.com/jenniferskay/kinematics-problems-01/master/pythonFiles/kayColorPalette.py">kayColorPalette.py</a>
# Specifying a set of colors that make up a color-blind friendly palette
#
# ## <a href = "https://raw.githubusercontent.com/jenniferskay/kinematics-problems-01/master/pythonFiles/kayHomogeneousTransformations.py">kayHomogeneousTransformations.py</a>
#
# This is an attempt to make it easier to work with homogeneous transformations in python without having to write everything from scratch. It's based on the <a href = "https://numpy.org/"> numpy</a> library. You may find it useful to take a look at this <a href = "https://numpy.org/devdocs/user/absolute_beginners.html"> numpy for absolute beginners</a> document.
#
# I use numpy matrices to represent homogeneous transforms so we can take advantage
# of the matrix multiplication functionality. For the full information you should go look at the code
#
#
# ## <a href = "https://raw.githubusercontent.com/jenniferskay/kinematics-problems-01/master/pythonFiles/kayHomogeneousTransformGraphics.py">kayHomogeneousTransformGraphics.py</a>
#
# Take a look at the source code to see the functionality that I provide.

# %% [markdown]
# <h1 style="color:#EE3377">
#      Problem Set
# </h1>
#
# #### (Starting with Problems that only use Translation)
#
#
# # Problem 01
#
# <hr>
#
# <ul>
#
# <h4 style="color:#EE3377">
#      IMPORTANT NOTE:
# </h4>
#
# <h4 style="color:#EE3377">
# This as an example problem - I have already solved all the parts of problem 1 for you below. You will need to repeat a lot of the stuff that I do in this problem in subsequent problems, and so it benefits you to walk through this slowly and review the code.
#     </h4>
# </ul>
# <hr>
#
#
#
#
# In figure 1 you can see:
# * The world (w) coordinate frame
# * The robot (r) coordinate frame
#     * To get from world coordinates to robot coordinates you need to move 10 units along w's x axis.
#
#
#
# <!-- <img src = "graphics/fig01e.jpg"> -->
# <img src = "https://raw.githubusercontent.com/jenniferskay/kinematics-problems-01/master/graphics/fig01e.jpg">
#
#
#
# ## Example Problem 01 Part A:
# Add a python code cell immediately below this one and write code that
# * Step 1: Creates global variables that are assigned the 4x4 matrix values for each of the following by figuring out the Trans that you need to do and then using the `ht.doTrans` function:
#
#   * $F_{w}^{r}$
#   * $ F_{r}^{w} $
#     <p>
#
# * Step 2: Creates global variables that are assigned the 4x4 matrix values for each of the following by assigning them the appropriate F trans
#     * $ T_{w}^{r} $
#     * $ T_{r}^{w} $
#     <p>
# * Step 3: Prints out information about what you've done (see Notes below)
#
# <p> </p>
#
# **Notes:**
# * I'm asking you to do it globally so that we can use these values in additional code cells later. Be sure to use decent variable names!!
#
# * You must print out <u>clear and informative </u>messages about the things you just created. Specifically, you should <u>start</u> by specifying what you're doing in English then:
#
#     * After creating the frame transformations you should print out both the frame transformation in words and also as a 4x4 matrix.
#     * After creating the homogeneous transformations you can just print out their matrices.
#
# <p> </p>

# %%
# Problem 1 Part A
# (Note: this is Dr. Kay's sample answer to problem 1 Part A. Run it to see the output.)
# (Additional note: the kayHomogeneousTransformations library contains the homogeneous transformation methods that Dr. Kay 
#             wrote to make things easier. I have already imported  above using the following command:
#    import kayHomogeneousTransformations as ht
# So I don't have to do it now.



# Note that I'm declaring all of the variables outside of functions so they will be global. 
# Yes, global variables are often evil, but in the case of Jupyter notebooks, we need to keep
# them global so that we can reuse them in future cells.

# F from w to r
print ("(Frame Transform) F from w to r is Trans (10, 0, 0) which is the following 4x4 matrix:" )
frame_transform_w_r = ht.doTrans(10,0,0)
print(frame_transform_w_r)
print() # add a blank line to make it more readable

# F from r to w
print ("(Frame Transform) F from r to w is Trans (-10, 0, 0) which is the following 4x4 matrix:" )
frame_transform_r_w = ht.doTrans(-10,0,0)
print(frame_transform_r_w)


# T from w to r
homogeneous_transform_w_r = frame_transform_r_w
print("\n(Homogeneous Transform) T from w to r is: ") # Note: the \n is a shorter way to add a newline 
print(homogeneous_transform_w_r)

# T from r to w
homogeneous_transform_r_w = frame_transform_w_r
print("\n(Homogeneous Transform) T from r to w is: ") 
print(homogeneous_transform_r_w)

# %% [markdown]
# <p> &nbsp; </p>
# <p> &nbsp; </p>
#
#
# ## Example Problem 01 Part B:
#
# While I may not have mentioned it before, it turns out that:
# * $ T_{w}^{r} $ is equal to the inverse of $T_{r}^{w} $
#
# and
#
# * $ F_{w}^{r} $ is equal to the inverse of $F_{r}^{w} $
#
#
# Step 1 (the only step): Create a new code cell immediately below this one, and write a small function to confirm that the matrix that you defined for
# $ T_{w}^{r}  $ really is the same as  the inverse of $T_{r}^{w} $
# and then call your function
#
# #### If they're not equal (or very close to equal) you should figure out what you did wrong and fix it.
#
# #### Important note: in my solution, I demo both the `np.array_equal` method as well as the `np.allclose` method (which returns True if two numpy arrays (aka our matrices) are element-wise equal while allowing for a small error. When our matrices get more complex you may need to use `np.allclose`
# See https://numpy.org/doc/stable/reference/generated/numpy.array_equal.html and https://numpy.org/doc/stable/reference/generated/numpy.allclose.html for more information, expecially about the additional arguments you might want to use for allclose

# %%
# Note: This is Dr. Kay's answer to Problem 1 Part B

# Note that I have already imported numpy above using the following command:
#    import numpy as np
# So I don't have to do it now.

def part1b():
    # using numpy matrix inversion
    homogeneous_transform_w_r_inverted = np.linalg.inv(homogeneous_transform_w_r)

    print ("*" * 90) # 90 stars in a row to make the output prettier

    # numpy equality
    if np.array_equal(homogeneous_transform_w_r_inverted, homogeneous_transform_r_w):
        print ("\nYay, the inverse of homogeneous_transform_w_r is equal to homogeneous_transform_r_w\n")
    else:
        print ("Hmmm, not identical")
    
        # tip: see https://numpy.org/doc/stable/reference/generated/numpy.allclose.html for info on additional parameters
        if np.allclose(homogeneous_transform_w_r_inverted, homogeneous_transform_r_w):
            print ("But they are close to equal")
        else: 
            print ("Something's wrong!")
    
    print ("*" * 90)

# Since I did it in a function, I need to remember to call it with an outdented call or nothing will happen!!
part1b()

# %% [markdown]
# <p> &nbsp; </p>
# <p> &nbsp; </p>
#
#
#
# ## Example Problem 01 Part C:
#
# Figure 2 includes the frames in figure 1, along with two additional points.
#
# Do the following:
# * Step 1: Figure out (just in your head or on paper) the location of the points in both world and robot coordinates just based on the measurements given (all the information you need should be there - do NOT assume the image is to scale!)
#
#     * So, for example, you would figure out that p1 is located at $(0, 0, 0)_w$  and $(-10, 0, 0)_r$
#          * Notice the subscripts above - that's how I'm indicating that the (0,0,0) location is relative to world coordinates and the (-10,0,0) is relative to robot coordinates
#
#
#
# * Step 2: Once you've figured out both points' locations relative to both frames:
#     * Step 2a: Add a new code cell below this cell
#     * Step 2b: Create and assign global variables with good names for both the points relative to both frames
#
#
# <img src = "https://raw.githubusercontent.com/jenniferskay/kinematics-problems-01/master/graphics/fig02c.jpg">
# <!-- <img src = "graphics/fig02c.jpg"> -->
#
# <h4 style="color:#EE3377">
#     IMPORTANT FACTOID: None of the images in this assignment are perfectly scaled - but you should assume that the numbers that have been written are correct!
# </h4>
#
# <p> &nbsp; </p>
# <p> &nbsp; </p>

# %%
# Note: this is Dr. Kay's sample answer to problem 1 Part C

p1_world = ht.makePoint(0,0,0)
p1_robot = ht.makePoint(-10,0,0)

p2_world = ht.makePoint(3.5, 0, -1.5)
p2_robot = ht.makePoint(-6.5, 0, -1.5)


for tempPair in ((p1_world, "p1_world"), (p1_robot, "p1_robot"), (p2_world, "p2_world"), (p2_robot, "p2_robot")):
    print ("\n" + tempPair[1]+":")
    print (tempPair[0])

# %% [markdown]
# <p> &nbsp; </p>
# <p> &nbsp; </p>
#
#
#
# ## Example Problem 01 Part D:
#
# Now let's see if the math works out.
#
# Create a new code cell below and write code that does the following:
# * Step 1: For p1, start with what you wrote in part C as the point's location in world coordinates and use $ T_{w}^{r} $ to convert it to robot coordinates
#
# * Step 2: For p2, start with what you wrote in part C as the point's location in robot coordinates and use $ T_{r}^{w} $ to convert it to world coordinates.
#
# * Step 3: Check your answers, does everything match what you got in part C?  (If it doesn't, figure out where you went wrong and fix it)
# <p> &nbsp; </p>
# <p> &nbsp; </p>

# %%
# This is Dr. Kay's sample Answer to Problem 01 Part D

    
# must use numpy's matmul to do the multiplication
p1_from_world_to_robot = np.matmul(homogeneous_transform_w_r, p1_world)
if np.array_equal(p1_from_world_to_robot, p1_robot):
    print("Yay! Multiplication worked for point p1")
else:
    print("************* Problem multiplication did NOT work for point p1")
        
        
p2_from_robot_to_world = np.matmul(homogeneous_transform_r_w, p2_robot)
if np.array_equal(p2_from_robot_to_world, p2_world):
    print("Yay! Multiplication worked for point p2")
else:
    print("************* Problem multiplication did NOT work for point p2")

# %% [markdown]
# <p> &nbsp; </p>
# <p> &nbsp; </p>
#
#
#
# ## Example Problem 01 Part E:
#
# ### I may not have mentioned before, but it turns out that the F transforms also represent the frames themselves, so we can use them for graphics.
#
# Add a code block below and write a function called `problem01_partE`
# that uses Dr. Kay's Homogeneous Graphics library to graph the w and r frames. Your function should also return the matplotlib fig and ax values so you could conceivably add to the graph later.
#
#
# <p> &nbsp; </p>
# <p> &nbsp; </p>

# %%
# This is my sample solution to Problem 1 part E
# You might want to look at the prototypes in the code for my kayHomogeneousTransformGraphics
#     so you can see the optional arguments

# note that I've already imported the graphics package above with the following command:
#          import kayHomogeneousTransformGraphics as hg
# so I don't need to do it now


# Since I was told not to create any globals, and the graphics requires some variable creation, I'd better do it
# in a function

def problem01_partE():
    
    # the x, y, and z limits define the range of the visible area. 
    # In this example everything we care about is between -3 and 11
    # 
    thingToPrint = "You can expand this window by dragging the botom right corner!"
    thingToPrint += "\nAlso click on the figure and drag your mouse to move it around"
    
    fig,ax = hg.createNewBlank3DFigure(xLim=(-3,11), yLim=(-3,11), zLim =(-3,11), 
                                       title=thingToPrint)
    
    # The default frame for the graphics has x going right, y going in, and z going up. I intentionally made world 
    # coordinates the same so that drawing is easier. 
    # It also means that I can just use a 4x4 identity matrix for world coordinates. 
    # I'll use the built in numpy identity function
    worldFrame = np.identity(4)

    # to get to the robot frame, in world coordinates, start with the world frame and then do F from world to robot
    robotFrame = np.matmul(worldFrame, frame_transform_w_r)
    
    # draw the two frames and add w and r to the axes
    hg.draw3DFrame(ax, worldFrame, labelExtra = "-w", colorChoice = "blue", axisLength = 3)
    hg.draw3DFrame(ax, robotFrame, labelExtra = "-r", colorChoice = "blue", axisLength = 3)
    
        
    # Returning fig and ax because the problem told us to (mostly for a demo in part F of the problem 
    return(fig,ax)
     
    
    
# remember to run the function!
# We're not using the return values in this part, so jupyter will just print them when it's done
# It'll look weird, something like the following:
'''
(<Figure size 432x288 with 1 Axes>,
 <Axes3DSubplot:title={'center':'You can expand this window by dragging the botom right corner!\nAlso click on the figure and drag your mouse to move it around'}, xlabel='X', ylabel='Y'>)
'''

# OK, here's the function call!
problem01_partE()

# %% [markdown]
# <p> &nbsp; </p>
# <p> &nbsp; </p>
#
# ## Example Problem 01 Part F:
#
#
# Add a code block below that first calls the `problem01_partE` function you wrote above and then adds in p1 and p2.
#
#
# <p> &nbsp; </p>
# <p> &nbsp; </p>

# %%
figPart1f, axPart1f = problem01_partE()

# Everything on the graph is plotted relative to the default frame for the graphics
# which has x pointing to the right, y pointing into the screen, and z pointing up.
# As I mentioned in the previous part, this problem has been set up so that is the same
# as world coordinates. So I can just plot the points in world coordinates and I'll be good. 

# I'm not going to print p1's coordinates, mostly to demo that I don't have to do so
hg.plot3DPoint(axPart1f, p1_world, xyzLabel=False, labelExtra="   p1", colorChoice="red")
hg.plot3DPoint(axPart1f, p2_world, labelExtra=" - p2", colorChoice="red")

plt.title("Look, I can change the title after the fact")

# %% [markdown]
# <p> &nbsp;</b>
# <p> &nbsp;</b>
#
# <h1 style="color:#EE3377">
#     <p></p>The actual work YOU have to do starts here ...
# </h1>
# Initially I'm going to get you to repeat a lot of the coding that I did above, with just some very minor changes. I encourage you to retype the code from scratch rather than just copy/paste and edit because you're likely to both get a better understanding of what's going on and also less likely to make errors.
#
#
# # Problem 2
# Note, this problem introduces new figures, but while they give you additional information, they don't change anything you've already seen - in other words, all of the problems in this assignment take place in the same world, I'm just showing you more and more information as we go on!
#
# ## Problem 2 Part A
#
# Figure 3 is the same as Figure 2, except 4 additional points have been added.
#
# * Step 1: Figure out (just in your head or on paper) the location of the additional points in both world and robot coordinates just based on the measurements given (all the information you need should be there - do NOT assume the image is to scale!)
#
#
# * Step 2: Once you've figured out both points' locations relative to both frames:
#     * Step 2a: Add a new code cell below this cell
#     * Step 2b: Create and assign global variables with good names for both the points relative to both frames
#
# <!-- <img src = "graphics/fig03e.jpg"> -->
# <img src = "https://raw.githubusercontent.com/jenniferskay/kinematics-problems-01/master/graphics/fig03e.jpg">
#
# <h4 style="color:#EE3377">
#     IMPORTANT FACTOID: None of the images in this assignment are perfectly scaled - but you should assume that the numbers that have been written are correct!
# </h4>
#
#
# <p> &nbsp; </p>
# <p> &nbsp; </p>

# %% [markdown]
# <p> &nbsp; </p>
# <p> &nbsp; </p>
#
# ## Problem 2 - Part B
#
# Now let's see if the math works out.
#
# Create a new code cell below and write code that does the following:
# * Step 1: For p3 and p4, start with what you wrote in part C as the point's location in world coordinates and use $ T_{w}^{r} $ to convert it to robot coordinates
#
# * Step 2: For p5 and p6 start with what you wrote in part C as the point's location in robot coordinates and use $ T_{r}^{w} $ to convert it to world coordinates.
#
# * Step 3: Check your answers, does everything match what you got in part A? If not, figure out where you went wrong and fix it.
#
#
#
# <p> &nbsp; </p>
# <p> &nbsp; </p>

# %% [markdown]
# <p> &nbsp; </p>
# <p> &nbsp; </p>
#
# ## Problem 2 - Part C
#
# Create a new code cell below. Then do **Just ONE** of the following two options:
#
# ### Quick option:
# It's totally fine to select this option:
#
# * Use the `problem01_partE` function I wrote earlier to draw the world and robot frames, and then plot all 6 points
#
# ### Alternate option (if you want to play more with the graphics):
#
# Draw the world and robot frames and plot all 6 points by creating your own problem02_partE function that is a twist on the code from `problem01_partE` - play with some of the parameters to the graphics functions to make your graph cooler looking - I've tried to put good comments into the kayHomogeneousTransformGraphics.py code that explain all the options. In addition, you may want to look at matplotlib to see what exactly it is that I did to create my library and other options that you could use.
#
# <p> &nbsp; </p>
# <p> &nbsp; </p>

# %% [markdown]
# <p> &nbsp;</b>
# <p> &nbsp;</b>
#
#
# <h1 style="color:#EE3377">
#    Problem 3
# </h1>
#
# Note, this problem introduces new figures, but while they give you additional information, they don't change anything you've already seen - in other words, all of the problems in this assignment take place in the same world, I'm just showing you more and more information as we go on!
#
# ## Problem 3 - Part A
#
# Figure 4 shows the relative position of another frame - "gripper coordinates"
#
# Add a python code cell immediately below this one and write code that
# * Creates global variables that are assigned the 4x4 matrix values for each of the following by figuring out the Trans that you need to do and then using the `ht.doTrans` function. (Use names that are consistent with the previous naming schemes)
#
#   * $ F_{g}^{r} $
#   * $ F_{r}^{g} $
#   * $ F_{g}^{w} $
#   * $ F_{w}^{g} $
#
#     <p>
# * Creates global variables that are assigned the 4x4 matrix values for each of the following by assigning them the appropriate F trans you just initialized.
#   * $ T_{g}^{r} $
#   * $ T_{r}^{g} $
#   * $ T_{g}^{w} $
#   * $ T_{w}^{g} $
#
#     <p>
#
#
#
#
# <p> &nbsp;</p>
#
#
# **Notes:**
#
# * You **MUST** print out <u>clear and informative </u>messages about the things you just created. Specifically, you should <u>start</u> by specifying what you're doing in English then:
#
#     * After creating the frame transformations you should print out both the frame transformation in words and also as a 4x4 matrix.
#     * After creating the homogeneous transformations you can just print out their matrices.
#
# <p> </p>
#
# <!--<img src = "graphics/fig04d.jpg"> -->
# <img src = "https://raw.githubusercontent.com/jenniferskay/kinematics-problems-01/master/graphics/fig04d.jpg">
#
#
#
# <h4 style="color:#EE3377">
#     IMPORTANT FACTOID: None of the images in this assignment are perfectly scaled - but you should assume that the numbers that have been written are correct!
# </h4>
#
# <p> &nbsp; </p>
# <p> &nbsp; </p>

# %% [markdown]
# ## Problem 3, Part B
#
# Figure 5 attempts to show you all the information that we've had so far. (You may also occasionally want to refer to previous figures when there are too many overlapping measurements in figure 5)
#
# Figure 5 also has a new point called p7 which is located at g's origin.
#
# #### Do the following:
# Step 1: Figure out (just in your head or on paper) the location of the all of the following just based on figure 4 (or the earlier figures)
# * points p1 through p6 in gripper coordinates,
# * point p7 in world and robot coordinates
#
#
# Step 2: Once you've figured out all the points' new locations relative to the frames:
# * Step 2a: Add a new code cell below this cell
# * Step 2b: Create and assign global variables with names that are consistent with the previous points created for all these new quantities.
#
#
# At this point, you have manually computed global variables for points 1-7 in all 3 coordinate frames. Let's do some testing to make sure that the frame transformations and points that you've computed are still all consistent.
#
# Step 3: Add additional code that uses $ T_{w}^{g} $ (that you computed above) to compute points p1 through p6 mathematically and store them in additional global variables. For example, you can compute p1 in gripper coordinates by matrix multiplying  $ T_{w}^{g} $ times $p1_w$
# <p>
#
# Step 4: Use $ T_{g}^{w}$ and $p7_g$  to mathematically compute $p7_w$
#
#
# Step 5: Uses the `np.array_equal` (and, if necessary, `np.allclose`) function to confirm that the new points you computed mathematically are equal to the points you created based on your work in your head or one paper.
# If they're not equal (or really close), figure out what you did wrong and fix it!!
#
# <p>
#
# <img src = "https://raw.githubusercontent.com/jenniferskay/kinematics-problems-01/master/graphics/fig05b.jpg">
#
#
#
# <!-- <img src = "graphics/fig05b.jpg"> -->
#
# <h4 style="color:#EE3377">
#     IMPORTANT FACTOID: None of the images in this assignment are perfectly scaled - but you should assume that the numbers that have been written are correct!
# </h4>
#
# <p> &nbsp; </p>
# <p> &nbsp; </p>

# %% [markdown]
# <p>&nbsp;</b>
# <p>&nbsp;</b>
#
#
# ## Problem 3 - Part C
# ### An alternate way to compute the FRAME transformations
#
# * If you have:
#     * 3 coordinate frames: A, B, and C
#     * The frame transforms  $ F_{A}^{B} $ and  $ F_{B}^{C} $
# * You can easily compute $ F_{A}^{C} $
#     * Fact: $ F_{A}^{C} $ is equal to the matrix multiplication of $ F_{A}^{B}$ times $ F_{B}^{C} $
#
# Add a python code cell below this one that does the following:
# * Step 1: Create new global variables whose names start with "alt" for:
#     * $ F_{w}^{g} $   *(call it alt_frame_transform_w_g)*
#     * $ F_{g}^{w} $   *(call it alt_frame_transform_g_w)*
#
#    <p>
#
# * Step 2: Use the above alternative frame translations to create alternateive variables for the homogeneous transformations
#     * $ T_{w}^{g} $   *(call it alt_homogeneous_transform_w_g)*
#     * $ T_{g}^{w} $   *(call it alt_homogeneous_transform_g_w)*
#
#  <p>
#
# * Step 3: Prints out a nice message that includes the values of all of these new transforms.
#
#      <p>
#
# * Step 4: Uses the `np.array_equal` (and, if necessary, `np.allclose`) function to confirm that your 4 alternate transformations are the same as the ones you defined in Part A. If they're not, figure out what you did wrong and fix it!
#
#
#
# <p> &nbsp; </p>
# <p> &nbsp; </p>

# %% [markdown]
# <p>&nbsp;</b>
# <p>&nbsp;</b>
#
# ## Problem 3 - Part D
#
# You would think that this multiplicative relationship would be the same for the homogeneous transformations, but it turns out that
#
# $ T_{A}^{C} $ **Does NOT equal**  matrix multiplication of $ T_{A}^{B}$ times $ T_{B}^{C} $
#
# <p>
#
# Finish the explanation that I have outlined in the next <u>Markdown</u> cell that explains why $ T_{A}^{C} $ **Does NOT equal**  matrix multiplication of $ T_{A}^{B}$ times $ T_{B}^{C} $
#
# <p>&nbsp;</b>
# <p>&nbsp;</b>

# %% [markdown]
# <p>&nbsp;</p>
# <p>&nbsp;</p>
#
# <h2 style="color:#EE3377">
#   Here is the outline of your answer to Problem 3 - Part D  ... double click on it to edit and finish the explanation
# </h2>
#
# ## Explanation of why $ T_{A}^{C} $ **Does NOT equal**  matrix multiplication of $ T_{A}^{B}$ times $ T_{B}^{C} $
#
# * We know (by definition) that we compute the homogeneous transformations based on the frame transformations. So, for example, we know that:
#     * $ T_{A}^{C} $ is equal to  $ F_{C}^{A} $
#     * $ T_{A}^{B}$  is equal to (Your answer here)
#     * $ T_{B}^{C} $  is equal to (Your answer here)
#
# <p></p>
#
# * So that means that $ T_{A}^{B}$ times $ T_{B}^{C} $ equals (fill in what it equals in terms of f transforms by substituting the appropriate ones for the T transforms above)
# <p> </p>
#
# * But wait - Above we said that $ T_{A}^{C} $ is equal to (Your answer here)
# <p> </p>
#
# * And (say something about how the last two sections are not equal !)
# <p> </p>
#
# #### Thus we have shown that $ T_{A}^{C} $ **Does NOT equal**  matrix multiplication of $ T_{A}^{B}$ times $ T_{B}^{C} $
#
# <p>&nbsp;</p>
# <p>&nbsp;</p>

# %% [markdown]
# <p> &nbsp;</b>
# <p> &nbsp;</b>
#
#
# <h1 style="color:#EE3377">
#    Problem 4
# </h1>
#
# Note, this problem introduces new figures, but while they give you additional information, they don't change anything you've already seen - in other words, all of the problems in this assignment take place in the same world, I'm just showing you more and more information as we go on!
#
# ## Problem 4 - Part A
#
# Figure 6 shows the relative position of yet another frame - "sensor coordinates" (s) to the others.
# * Sensor coordinates' x axis is the same as gripper coordinates' x axis
# * Sensor coordinates' y axis is in the negative direction of gripper's z axis
# * Sensor coordinates' z axis is the same as gripper coordinates' y axis
# * The origins of sensor and gripper coordinates are located at the same point.
#
# Add a python code cell immediately below this one and write code that
# * Step 1: Creates global variables that are assigned the 4x4 matrix values for the Frame transformations $ F_{g}^{s} $  and $ F_{s}^{g} $ by figuring out the Rotation that you need to do (in your head) and then coding it up using the appropriate rotation function. In other words ...
# <ul style="color:#3377EE">
#
#      * Look at Figure 6
#      * Figure out the relationship between the g frame and the s frame.
#          * For example, you might conclude that $ F_{g}^{s} $ = RotZ(45 degrees)  (Important Note - this is not the correct answer, but I'm going to stick with the example just so we have something concrete to go on)
#      * Use that information to create an assignment statement based on your conclusion
#          * For example, if $ F_{g}^{s} $ did equal RotZ(45 degrees), then you could write a line of code: <br> ` frame_transform_g_s= ht.degreesRotZ(45)`
#          * You can figure out how to use the rotation functions / what their interfaces are by looking at the code in the kayHomogeneousTransformations.py file.
#
# </ul>
#
#
# * Step 2: Creates variables for the Homogeneous Transformations $ T_{g}^{s} $  and $ T_{s}^{g} $   based on your new Frame Transformations
#
#
# * Step 3: Create a new variable that represents $p7_s$ (i.e. p7 in s coordinates) that is assigned the matrix product of $ T_{g}^{s} $ and $p7_g$. Confirm that  is equal to $p7_g$ (this is only the case because both of which should of course be (0,0,0), because s and g share an origin right?!? )
#
#
#
# <p> &nbsp;</p>
#
#
# **Notes:**
#
# * You **MUST** print out <u>clear and informative </u>messages about the things you just created. Specifically, you should <u>start</u> by specifying what you're doing in English then:
#
#     * After creating the frame transformations you should print out both the frame transformation in words and also as a 4x4 matrix.
#     * After creating the homogeneous transformations you can just print out their matrices.
#
# <p> </p>
#
# <!-- <img src = "graphics/fig06c.jpg">   -->
# <img src = "https://raw.githubusercontent.com/jenniferskay/kinematics-problems-01/master/graphics/fig06c.jpg">
#
#
#
# <h4 style="color:#EE3377">
#     IMPORTANT FACTOID: None of the images in this assignment are perfectly scaled - but you should assume that the numbers that have been written are correct!
# </h4>
#
# <p> &nbsp; </p>
# <p> &nbsp; </p>

# %% [markdown]
# <p> &nbsp;</b>
# <p> &nbsp;</b>
#
#
# ## Problem 4 - Part B:
#
# Some students might complete a problem like part 4A above and conclude that they've correctly computed $ T_{g}^{s} $  and $ T_{s}^{g} $ correctly based on checking just the point p7. But you would never do that, would you. p7 is the one point that is easiest to get right if your frames differ just by a rotation. Let's do some more checking.
#
#
# Step 1: Figure out (just in your head or on paper) the location of points p1 through p6 in sensor coordinates just based on the information in Figure 7 (feel free to refer to earlier figures too, since figure 7 is getting pretty crowded!)
#
# Step 2: Once you've figured out all the points' new locations relative to the frames:
# * Step 2a: Add a new code cell below this cell
# * Step 2b: Create and assign global variables with names that are consistent with the previous points created for all these new quantities.
#
# Step 3: Add additional code that uses $ T_{g}^{s} $  and the location of points p1 through p3 in gripper coordinates to do a mathematical computation of where points p1 through p3 are  in sensor coordinates. Write code that compares the values you get with the global variables you created in step 2. If they're not the same, figure out what you did wrong in part A or part B and fix it!
#
# Step 4: Add additional code that uses $ T_{s}^{g} $  and the location of points p4 through p6 in sensor coordinates to do a mathematical computation of where points p4 through p6 are in gripper coordinates. Write code that compares the values you get with the global variables you created in step 2. If they're not the same, figure out what you did wrong in part A or part B and fix it!

# %% [markdown]
# <p> &nbsp;</b>
# <p> &nbsp;</b>
#
#
# ## Problem 4 - Part C:
# Now we're going to figure out an alternate version of $ F_{g}^{s} $  and $ F_{s}^{g} $ just to show how crazy we can be.
#
# We learned earlier that we can cascade Frame transformations<br> (i.e. if we have frames A, B, and C, then $ F_{A}^{C} $ is equal to the matrix multiplication of $ F_{A}^{B}$ times $ F_{B}^{C} $ ).
#
# Let's start by trying a seriously insane sequence of multiplications and still if we get the same value for $ F_{g}^{s} $
#
#
# * Step 1: Print out a copy of figure 6, and using a pencil draw the intermediate frames that the following seqence of frame transformations takes you through to convince yourself that it actually does result in you starting at g and ending up at s (nothing to turn in for this step, but you want to do it so you understand what's going on
#     * $ F_{g}^{w} $
#     * $ F_{w}^{r} $
#     * RotY (180 degrees)
#     * Trans (0,0,7)
#     * RotZ (180 degrees)
#     * Trans (8,0,0)
#     * RotX (90 degrees)
#
#     <p> &nbsp;</b>
#
# * Step 2: Write code that Creates a new global variable called  `alt_frame_transform_g_s` that computes $ F_{g}^{s} $ by matrix multiplying the list above.
#
# <p> &nbsp;</b>
#
# * Step 3: Confirm that `alt_frame_transform_g_s` is (close to) equal to the version of $ F_{g}^{s} $ you originally came up with in part A. If it's not, figure out where you went wrong and fix it.
#
#
# <h4 style="color:#EE3322">
# IMPORTANT FACTOID: Now that we've got rotations in the mix the matrix multiplications are not always 100% perfect. When I did step 3
# `np.array_equal` returned False, but `np.array_close` returned True.
# </h4>
#
#
#
#
# <p> &nbsp;</b>
#
# * Step 4: Create a global variable called `alt_frame_transform_s_g` that equals the matrix inverse of `alt_frame_transform_g_s`   (go back to problem 1 to see how to invert a matrix in numpy).
#     * Confirm that `alt_frame_transform_s_g` is (close to) equal to the version of $ F_{s}^{g} $ you originally came up with in part A. If it's not, figure out where you went wrong and fix it!
#
#
# <p> &nbsp; </p>
# <p> &nbsp; </p>

# %% [markdown]
# <p> &nbsp;</b>
# <p> &nbsp;</b>
#
#
# ## Problem 4 - Part D:
#
# In part C I gave a suggestion of "the long way" to get a frame transform from g to s.
#
# In this step you will need to come up with a new "long way" for each of the following transformations:
# * $ F_{s}^{r} $
# * $ F_{r}^{w} $
# * $ F_{w}^{g} $
#
#
#
# ####  For each Transformation, you will Need to create both a Markdown frame and a Code Frame
#
#
# * Step 1: Come up with a new "crazy" way to compute each of the Frame transforms listed above. List the steps to do your crazy transformation. Each of your "crazy" ways must include:
#     * At least one existing frame transform we've already defined
#     * At least two rotations about two different axes
#     * At least two transformations
# #### Note: yes, you will do unnecessary stuff, that's the point - you'll have to do some rotations and then undo them in different ways, the point is to get used to converting between frames and doing rotations and translations.
#
# * Step 2: List your steps in a new Markdown frame like I listed mine in part 4C
#
# * Step 3: Implement your steps in a new code frame like you did for 4C
#
# * Step 4: If you don't already have a "simple" version of this transform created in an earlier step (e.g. I already did * $ F_{r}^{w} $ in Problem 1A) then create one just by looking at the relative locations of the two frames.
#
# * Step 5: Compare your simple answer with your crazy one. If they're not the same, figure out what you did wrong.

# %% [markdown]
# <p> &nbsp;</b>
# <p> &nbsp;</b>
#
#
# ## Problem 4 - Part E: (The grand finale)
#
# We've now figured out crazy ways to do each of the following:
# * $ F_{g}^{s} $
# * $ F_{s}^{r} $
# * $ F_{r}^{w} $
# * $ F_{w}^{g} $
#
# Theoretically, if you multiply them all together, you should get $ F_{g}^{g} $ which should just be the identity matrix, right? Create a code cell that does that, and make sure you get the identity matrix.
